# %% [markdown]
# <a href="https://colab.research.google.com/github/shafqat202/hi/blob/main/collab%20colaboration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hi from collab")
# Out:
# hi from collab

# %% [markdown]
# **tere naam**

# %%
i=input("enter Ur name: ").title()
print(f"hi {i} .Welcome to this cruel world")
# Out:
# hi Shafat Ahmed .Welcome to this cruel world

# %%
print ("modified ")
# Out:
# modified
